# %%
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
import osmnx as ox
import pandas as pd

# %matplotlib inline

ox.config(log_console=True, use_cache=True)
weight_by_length = False

ox.__version__
# Out:
# '0.15.1'

# %%
path = '/Users/andrewrenninger/Desktop/R/git/networks/data/'
os.chdir(path)

# %%
camps = pd.read_csv("camps/camps.csv")

# %%
camps.head()
# Out:
#            X          Y                    name
# 0  -6.865540  26.831305     Dakhla Refugee Camp
# 1  -8.010650  27.513829   Boujdour Refugee Camp
# 2  -8.023589  27.739910   El Aaiún Refugee Camp
# 3  -8.720793   7.025102       Bahn Refugee Camp
# 4  40.286872   0.190007  Dagahaley Refugee Camp

# %%
def reverse_bearing(x):
    return x + 180 if x < 180 else x - 180

# %%
bearings = {}

for i in np.arange(1, camps.shape[0]):
    print(datetime.datetime.now(), camps.name[i])
    
    name = camps.name[i]
    query = (camps.Y[i], camps.X[i])
    
    try: 
        G = ox.graph_from_point(query, dist = 1000)
    except:
        pass
    
   # if G.edges < 100:
   #     pass
   # 
   # else:
    
    Gu = ox.add_edge_bearings(ox.get_undirected(G))
    
    if weight_by_length:
        # weight bearings by length (meters)
        city_bearings = []
        for u, v, k, d in Gu.edges(keys=True, data=True):
            city_bearings.extend([d['bearing']] * int(d['length']))
        b = pd.Series(city_bearings)
        bearings[name] = pd.concat([b, b.map(reverse_bearing)]).reset_index(drop='True')
    else:
        # don't weight bearings, just take one value per street segment
        b = pd.Series([d['bearing'] for u, v, k, d in Gu.edges(keys=True, data=True)])
        bearings[i] = pd.concat([b, b.map(reverse_bearing)]).reset_index(drop='True')
# Out:
# 2020-06-09 16:28:59.057337 Boujdour Refugee Camp
# 2020-06-09 16:29:00.441091 El Aaiún Refugee Camp
# 2020-06-09 16:29:02.894725 Bahn Refugee Camp
# 2020-06-09 16:29:03.950045 Dagahaley Refugee Camp
# 2020-06-09 16:29:07.371236 Melkadida Refugee Camp
# 2020-06-09 16:29:11.800669 Heleweyen Refugee Camp
# 2020-06-09 16:29:14.633696 Kobe Refugee Settlement
# 2020-06-09 16:29:20.437735 Bokolmanyo Refugee Camp
# 2020-06-09 16:29:25.887929 Hagadera Refugee Camp
# 2020-06-09 16:29:29.236806 Ifo 2 Refugee Camp
# 2020-06-09 16:29:33.743239 Buramino Refugee Settlement
# 2020-06-09 16:29:35.201922 Ampain
# 2020-06-09 16:29:36.031703 Boynuyoğun
# 2020-06-09 16:29:36.749152 Camp de réfugiés de Gondje مخيم قونجي
# 2020-06-09 16:29:39.253609 Amboko Refugee Camp
# 2020-06-09 16:29:40.338015 Al Zaatari Refugee Camp
# 2020-06-09 16:29:42.576325 Shagarab-III Refugee Camp
# 2020-06-09 16:29:43.911469 Shagarab-I Refugee Camp
# 2020-06-09 16:29:45.330616 Shagarab-II Refugee Camp
# 2020-06-09 16:29:46.680054 Kouankan
# 2020-06-09 16:29:48.107755 Beydağı refugee camp
# 2020-06-09 16:29:49.488119 Gawilan Refugee Camp
# 2020-06-09 16:29:51.003431 Arbat Refugee Camp
# 2020-06-09 16:29:52.276776 Dzaleka Refugee Camp
# 2020-06-09 16:29:53.916535 Abala Refugee Camp
# 2020-06-09 16:29:54.913744 Awsard Refugee Camp
# 2020-06-09 16:29:59.274316 Marratane Refugee Camp
# 2020-06-09 16:30:05.302986 Adjuong Thok Refugee Camp
# 2020-06-09 16:30:07.737142 Muhama refugee camp
# 2020-06-09 16:30:11.862912 Doholo Refugee Camp
# 2020-06-09 16:30:25.753201 Sayam Forage Refugee Camp
# 2020-06-09 16:30:31.160008 Wad Sharefay
# 2020-06-09 16:31:07.345603 Goz Beida refugee camp
# 2020-06-09 16:31:12.277031 Treguine Refugee Camp
# 2020-06-09 16:31:17.448474 Gaga refugee camp
# 2020-06-09 16:31:21.048478 Kounougou Refugee Camp
# 2020-06-09 16:31:33.456389 Milé Refugee Camp
# 2020-06-09 16:31:40.688549 Dar as Salam refugee camp
# 2020-06-09 16:31:49.530078 Maing Khaung Refugee Site
# 2020-06-09 16:31:53.099136 Basirma Refugee Camp
# 2020-06-09 16:31:56.704051 Islahiye Refugee Camp
# 2020-06-09 16:32:00.529632 Mugumbwa refugee camp
# 2020-06-09 16:32:04.270914 Qushtapa Refugee Camp
# 2020-06-09 16:32:11.016377 Sherkole Refugee Camp
# 2020-06-09 16:32:13.724414 Adiyaman Refugee Camp
# 2020-06-09 16:32:25.452926 Hitsats Refugee Camp
# 2020-06-09 16:32:40.108885 Um Gargour Refugee Camp
# 2020-06-09 16:32:41.614081 Dzaleka Refugee Camp
# 2020-06-09 16:33:01.422894 Border Post 8 Refugee Site
# 2020-06-09 16:33:04.254496 Camp 18
# 2020-06-09 16:33:30.214073 Camp 16 - Bagghona-Putibonia Refugee Camp
# 2020-06-09 16:33:41.970380 Kule Refugee Camp
# 2020-06-09 16:33:44.056245 Tierkidi Refugee Camp
# 2020-06-09 16:33:46.147684 Nguenyyiel Refugee Camp
# 2020-06-09 16:33:48.220784 Jewi Refugee Camp
# 2020-06-09 16:33:50.245656 Kulagaru Refugee Site
# 2020-06-09 16:33:53.793719 Pamir Refugee Camp
# 2020-06-09 16:33:57.590515 Tsore Refugee Camp
# 2020-06-09 16:33:59.894605 Mai Aini Refugee Camp
# 2020-06-09 16:34:07.789989 Kamchijin Prayer Ground Refugee Site
# 2020-06-09 16:34:15.408948 Damara Arrival Centre Refugee Site
# 2020-06-09 16:34:19.681714 M'Bera Refugee Camp
# 2020-06-09 16:34:48.485761 Umbazah Rock Side Camp Refugee Site
# 2020-06-09 16:34:51.240519 Shimelba Refugee Camp
# 2020-06-09 16:34:56.457868 Tabareybarey Refugee Camp
# 2020-06-09 16:34:59.181863 Mangaize Refugee Camp
# 2020-06-09 16:35:02.391683 Darashakran Refugee Camp
# 2020-06-09 16:35:04.737405 Kawergosk Refugee Camp
# 2020-06-09 16:35:09.547081 Nduta Refugee Camp
# 2020-06-09 16:35:12.615553 Mtendeli Refugee Camp
# 2020-06-09 16:35:15.647770 Kebribeyah Refugee Camp
# 2020-06-09 16:35:24.255444 መዓስከር ስደተኛታት ኤርትራውያን  ዓዲ ሓርሽ  Adi Harush Refugee Camp
# 2020-06-09 16:35:30.455873 Nyarugusu Refugee Camp
# 2020-06-09 16:35:35.541733 Aysaita Refugee Camp
# 2020-06-09 16:35:40.698190 Kario Refugee Camp
# 2020-06-09 16:35:51.677458 Okugo RefugeeCamp
# 2020-06-09 16:35:54.304295 Berahle Refugee Camp
# 2020-06-09 16:36:02.107027 Tongo Refugee Camp
# 2020-06-09 16:36:05.061890 Gure-Shombola Refugee Camp
# 2020-06-09 16:36:06.957736 Azraq Refugee Camp
# 2020-06-09 16:36:11.702378 Emira Jordanian Camp (EJC)
# 2020-06-09 16:36:13.882784 Luwani Refugee Camp
# 2020-06-09 16:36:16.183258 Domiz 1 Refugee Camp
# 2020-06-09 16:36:20.309507 Bambasi Refugee Camp
# 2020-06-09 16:36:22.547023 Mboti Refugee Camp
# 2020-06-09 16:36:26.906735 Lusenda Refugee Camp
# 2020-06-09 16:36:32.044992 Mulongwe Refugee Camp
# 2020-06-09 16:36:34.780299 Musasa Refugee Camp
# 2020-06-09 16:36:37.620154 Mole Refugee Camp
# 2020-06-09 16:36:46.850791 Boyabu Refugee Camp
# 2020-06-09 16:36:49.616099 Bili Refugee Camp
# 2020-06-09 16:36:51.898331 Karkamis Refugee Camp
# 2020-06-09 16:36:54.158079 Cevdetiye Refugee Camp
# 2020-06-09 16:36:57.559467 Dosseye Refugee Camp
# 2020-06-09 16:37:02.499727 Yayladagi Refugee Camp
# 2020-06-09 16:37:06.116010 Yayladagi Refugee Camp
# 2020-06-09 16:37:09.403440 Apaydin Refugee Camp
# 2020-06-09 16:37:12.459313 Suruc Refugee Camp
# 2020-06-09 16:37:15.468772 Nizip-1 Refugee Camp
# 2020-06-09 16:37:18.254007 Nizip-2 Refugee Camp
# 2020-06-09 16:37:20.502821 Akcakale Refugee Camp
# 2020-06-09 16:37:22.889031 Elbeyli Refugee Camp
# 2020-06-09 16:37:25.831834 Oncupinar Refugee Camp
# 2020-06-09 16:37:28.487324 Midyat Refugee Camp
# 2020-06-09 16:37:31.485349 Saricam Refugee Camp
# 2020-06-09 16:37:34.572279 Ceylanpinar Refugee Camp
# 2020-06-09 16:37:36.467527 Nyabihake Refugee Camp
# 2020-06-09 16:37:40.751234 Kiziba refugee camp
# 2020-06-09 16:37:44.066939 KIgeme refugee camp
# 2020-06-09 16:37:47.591896 Mae La Refugee Camp
# 2020-06-09 16:37:49.943793 Ban Mai Nai Soi Refugee Camp
# 2020-06-09 16:37:52.074710 Ban Mae Surin Refugee Camp
# 2020-06-09 16:37:54.264234 Kilo 26 Refugee Camp
# 2020-06-09 16:37:56.301156 Al Kashafa Refugee Camp
# 2020-06-09 16:37:58.336266 Al Redis1 Refugee Camp
# 2020-06-09 16:38:01.956075 Little Wlebo Refugee Camp
# 2020-06-09 16:38:08.286876 Um Sangour Refugee Camp
# 2020-06-09 16:38:10.743637 Al Redis2 Refugee Camp
# 2020-06-09 16:38:19.143958 Dabat Bosin Refugee Camp
# 2020-06-09 16:38:21.109808 Al Alagaya Refugee Camp
# 2020-06-09 16:38:23.530572 Rawan Bapt. C. IDP Camp
# 2020-06-09 16:38:26.195690 Hka Shi IDP Camp
# 2020-06-09 16:38:28.445091 Abuda Refugee Camp
# 2020-06-09 16:38:33.122679 Kakuma I Refugee Camp
# 2020-06-09 16:38:39.064903 Kakuma IV Refugee Camp
# 2020-06-09 16:38:48.086632 Kakuma III Refugee Camp
# 2020-06-09 16:39:03.510308 Kaya Refugee Camp
# 2020-06-09 16:39:05.451604 Nyori Refugee Camp
# 2020-06-09 16:39:08.352737 Yusuf Batil Refugee Camp
# 2020-06-09 16:39:11.936488 Nu Po Refugee Camp
# 2020-06-09 16:39:14.190746 Umpiem Refugee Camp
# 2020-06-09 16:39:16.123507 Mae La Oon Refugee Camp
# 2020-06-09 16:39:18.486819 Ban Don Yang Refugee Camp
# 2020-06-09 16:39:20.578501 Anyake
# 2020-06-09 16:39:22.480719 Rindibin Camp
# 2020-06-09 16:39:25.162869 Daware Camp
# 2020-06-09 16:39:27.528961 Central Primary School Damboa
# 2020-06-09 16:39:30.276968 Old Secetariat Camp
# 2020-06-09 16:39:33.016283 Nysc Camp Borno
# 2020-06-09 16:39:37.141342 Agric IDP Camp
# 2020-06-09 16:39:39.640504 Egyeikrom
# 2020-06-09 16:39:41.962234 Ngari-singo
# 2020-06-09 16:39:44.597967 Makpandu
# 2020-06-09 16:39:46.807970 Lasu
# 2020-06-09 16:39:48.906882 Wulu center
# 2020-06-09 16:39:51.082817 Pibor
# 2020-06-09 16:39:53.768583 Mingkaman
# 2020-06-09 16:39:56.769930 Kormuokony
# 2020-06-09 16:39:58.720157 Man-Angui
# 2020-06-09 16:40:00.559642 Pagai
# 2020-06-09 16:40:02.986773 Magar
# 2020-06-09 16:40:05.105870 Yida
# 2020-06-09 16:40:08.867720 Donzumga Primary School Refugee site
# 2020-06-09 16:40:11.224013 Belom
# 2020-06-09 16:40:14.558533 Old Hospital Camp Refugee Site
# 2020-06-09 16:40:17.943315 Taung Paw Refugee Site
# 2020-06-09 16:40:21.129104 Khaung Doke Khar Refugee Site
# 2020-06-09 16:40:23.727301 Baw Du Pha 2 Refugee Site
# 2020-06-09 16:40:27.684518 Mayo Farrang Refugee site
# 2020-06-09 16:40:29.848808 Angwan Kara Refugee site
# 2020-06-09 16:40:34.090048 Sabon Peggi Refugee site
# 2020-06-09 16:40:36.248185 Shagari Quarters Camp Refugee site
# 2020-06-09 16:40:38.502113 Gadamayo Bango Refugee site
# 2020-06-09 16:40:40.586311 Red-Bricks (IDP) Camp Refugee site
# 2020-06-09 16:40:44.519626 Vocational Training Centre Refugee site
# 2020-06-09 16:40:47.233322 Ten Housing Quarters Refugee site
# 2020-06-09 16:40:50.155225 Estate Camp Refugee site
# 2020-06-09 16:40:52.408859 Hausari Primary School Damboa Refugee site
# 2020-06-09 16:40:54.772368 Sangaya Refugee Site
# 2020-06-09 16:40:58.186739 Motor Park Idp Camp Refugee Site
# 2020-06-09 16:41:02.425024 Masarmari Refugee Site
# 2020-06-09 16:41:05.485553 1000 Camp Dikwa Refugee Site
# 2020-06-09 16:41:08.799394 Ministry Of Works Camp Refugee Site
# 2020-06-09 16:41:12.802991 Shehu Musta Ii Refugee Site
# 2020-06-09 16:41:16.767680 Gssss Camp Bama Refugee Site
# 2020-06-09 16:41:21.883858 Wege Arrival Centre Refugee Site
# 2020-06-09 16:41:25.791826 Aisha Buhari Camp Refugee Site
# 2020-06-09 16:41:29.628963 Magistrate Refugee Site
# 2020-06-09 16:41:33.278837 Ggss Gajiganna Camp Refugee Site
# 2020-06-09 16:41:35.985744 Police Barracks Refugee site
# 2020-06-09 16:41:38.482277 Mobile Clinic Refugee site
# 2020-06-09 16:41:41.807267 Police Doki Refugee site
# 2020-06-09 16:41:44.718579 Upper Court Refugee site
# 2020-06-09 16:41:47.360158 Unity Camp Refugee site
# 2020-06-09 16:41:49.760003 Bulamatari Camp Refugee Site
# 2020-06-09 16:41:51.855226 Stadium Camp Refugee Site
# 2020-06-09 16:41:55.463631 Gardener Low Cost Refugee Site
# 2020-06-09 16:41:59.771766 Musari Camp Refugee Site
# 2020-06-09 16:42:04.311106 Custom House Refugee Site
# 2020-06-09 16:42:06.685181 AD-2000 Tharthana cpd Refugee Site
# 2020-06-09 16:42:10.324165 Shuwari Gaya Refugee Site
# 2020-06-09 16:42:12.920445 Yawuri Camp Refugee Site
# 2020-06-09 16:42:16.010616 Fulatari Refugee Site
# 2020-06-09 16:42:18.846360 Fannamri Refugee Site
# 2020-06-09 16:42:21.560066 Allamin Dagash Garage Refugee Site
# 2020-06-09 16:42:27.572188 Dalorima Refugee Site
# 2020-06-09 16:42:29.888783 Yajiwa Camp Kusheri Refugee Site
# 2020-06-09 16:42:34.552090 Ali Dawari I Refugee Site
# 2020-06-09 16:42:38.892247 Kaduwa I Refugee Site
# 2020-06-09 16:42:43.704391 Ali Dawari II Refugee Site
# 2020-06-09 16:42:48.667168 Yejiwa Borehole Camp Refugee Site
# 2020-06-09 16:42:56.252534 PTP Camp
# 2020-06-09 16:43:00.318219 nan
# 2020-06-09 16:43:03.351354 Bantiue
# 2020-06-09 16:43:10.555026 Fau 5
# 2020-06-09 16:43:21.582536 nan
# 2020-06-09 16:43:24.552704 Pugnido 2
# 2020-06-09 16:43:27.204382 turkoglu
# 2020-06-09 16:43:30.573512 Kalinga
# 2020-06-09 16:43:35.172407 Bele
# 2020-06-09 16:43:37.769162 Meri
# 2020-06-09 16:43:44.285695 Kaka2
# 2020-06-09 16:43:47.287524 Barda
# 2020-06-09 16:43:49.455437 Muna Da'Alti 1B Refugee Site
# 2020-06-09 16:43:56.206732 Muna Da'Alti 1A Refugee Site
# 2020-06-09 16:44:00.236041 Al-Kawthar Camp
# 2020-06-09 16:44:02.862144 Najaf RHU Camp
# 2020-06-09 16:44:09.754083 Al-Khalidiya Markazi camp
# 2020-06-09 16:44:12.145665 Al Salam / al takia al kasnazania
# 2020-06-09 16:44:26.290878 Scout Camp / Gazaliya
# 2020-06-09 16:44:30.397924 Al Jamea'a
# 2020-06-09 16:44:35.949997 Kadhra'a
# 2020-06-09 16:44:41.257769 Hajjaj Camp / Rub-Hall
# 2020-06-09 16:44:44.963375 Basateen At Sheuokh
# 2020-06-09 16:44:48.148443 Barzinja
# 2020-06-09 16:44:51.889030 Abba Kura Hassan Refugee Site
# 2020-06-09 16:44:54.694736 Muna Garage El Badawe Refugee Site
# 2020-06-09 16:44:57.589677 Muna Da'Alti 2 Refugee Site
# 2020-06-09 16:45:00.853350 Muna Da`Alti 2B Refugee Site
# 2020-06-09 16:45:05.980431 Muna Mallam Kori Refugee Site
# 2020-06-09 16:45:13.438709 Muna Da'Alti 2A Refugee Site
# 2020-06-09 16:45:16.974599 Muna Moforo Refugee Site
# 2020-06-09 16:45:34.934968 Muna Asheri Camp Refugee Site
# 2020-06-09 16:45:38.086715 Bajauro Camp Refugee Site
# 2020-06-09 16:45:40.769319 Fillin Baba Makinta Refugee Site
# 2020-06-09 16:45:43.434402 Gidan Mongoro Refugee Site
# 2020-06-09 16:45:47.401222 Bamodu House Refugee Site
# 2020-06-09 16:45:51.542380 Fato Kura Refugee Site
# 2020-06-09 16:45:55.214129 Alhaji Adam House 2 Refugee Site
# 2020-06-09 16:46:00.287339 Alhaji Adams House Refugee Site
# 2020-06-09 16:46:05.194038 Wade -Wade Layin Bola Refugee Site
# 2020-06-09 16:46:09.392691 Kirenuwa Camp Refugee Site
# 2020-06-09 16:46:13.225628 Kangarmaka Camp Refugee Site
# 2020-06-09 16:46:17.070228 Biafra Camp Refugee Site
# 2020-06-09 16:46:20.552494 Isa Gamai Camp Refugee Site
# 2020-06-09 16:46:23.432096 Bolorin Burin Refugee Site
# 2020-06-09 16:46:26.231594 Hkau Shau (BP 12) Refugee Site
# 2020-06-09 16:46:28.258704 Ansar Camp Refugee Site
# 2020-06-09 16:46:32.326552 Real Form Camp Refugee Site
# 2020-06-09 16:46:37.685197 Pampas Street Camp Refugee Site
# 2020-06-09 16:46:41.540395 Railway Terminus Camp Refugee Site
# 2020-06-09 16:46:45.776811 Kawar Maila Refugee Site
# 2020-06-09 16:46:50.375156 Ghulam Banda Refugee Site
# 2020-06-09 16:46:52.445481 Ghulam Banda Refugee Site
# 2020-06-09 16:46:54.815630 Chakdara Refugee Site
# 2020-06-09 16:46:57.110205 Chakdara Refugee Site
# 2020-06-09 16:47:00.293839 Zar Karez Refugee Site
# 2020-06-09 16:47:02.861466 Jan Mai Kawng Bapt. C. Refugee Site
# 2020-06-09 16:47:06.294624 Pa Dauk Myaing(Pa La Na) Refugee Site
# 2020-06-09 16:47:08.942736 Oblan Refugee site
# 2020-06-09 16:47:12.633955 Khaki Refugee site
# 2020-06-09 16:47:16.487503 Lisu Bapt.C. Maw Shan Vil. Seik Mu Refugee Site
# 2020-06-09 16:47:23.017811 Ajigab Camp Refugee Site
# 2020-06-09 16:47:26.170688 Ajajari camp Reffugee Site
# 2020-06-09 16:47:28.294907 Temporary Karshen Kwalta Camp Refugee Site
# 2020-06-09 16:47:32.984063 Bulabulin Gaura Refugee Site
# 2020-06-09 16:47:36.867396 Umarari Camp Refugee Site
# 2020-06-09 16:47:40.877233 Ajijari camp Reffugee Site
# 2020-06-09 16:47:44.892357 Goni Kyarimi Refugee Site
# 2020-06-09 16:47:48.002218 Alhaji Bashir Liman House Refugee Site
# 2020-06-09 16:47:51.380617 Campo Camp Refugee Site
# 2020-06-09 16:47:54.782179 Kaleri Babangida Refugee Site
# 2020-06-09 16:47:58.326878 Al-Yakub Reffugee Camp
# 2020-06-09 16:48:03.048475 Annur Camp Refugee Site
# 2020-06-09 16:48:06.580305 Mala Sheriff Construction Company Refugee Site
# 2020-06-09 16:48:09.731601 Bullet Quarters Camp Refugee Site
# 2020-06-09 16:48:17.268563 Dala Standard Refugee Site
# 2020-06-09 16:48:20.704898 Dogongida Camp Refugee Site
# 2020-06-09 16:48:24.788791 Karantina Refugee Site
# 2020-06-09 16:48:29.760769 Sabon Gari 2 Refugee Site
# 2020-06-09 16:48:32.911074 Kessa Kura Refugee Site
# 2020-06-09 16:48:35.061086 Al-Haji Tar 1 Reffugee Camp
# 2020-06-09 16:48:38.318412 Al-Haji Tar 2 Reffugee Camp
# 2020-06-09 16:48:41.167006 Sanawuya Refugee Site
# 2020-06-09 16:48:44.528798 Old Maiduguri Police Station Camp Refugee Site
# 2020-06-09 16:48:48.523605 Fulatari Farin Ruwa Refugee Site
# 2020-06-09 16:48:55.248284 Kuru Camp Reffugee Site
# 2020-06-09 16:49:01.161381 VIO camp Reffugee Site
# 2020-06-09 16:49:06.783572 Ungwan Abuja Refugee Site
# 2020-06-09 16:49:09.730626 Pawari Refugee Site
# 2020-06-09 16:49:14.112593 St Hillary Reffugee Site

# %%
def count_and_merge(n, bearings):
    # make twice as many bins as desired, then merge them in pairs
    # prevents bin-edge effects around common values like 0° and 90°
    n = n * 2
    bins = np.arange(n + 1) * 360 / n
    count, _ = np.histogram(bearings, bins=bins)
    
    # move the last bin to the front, so eg 0.01° and 359.99° will be binned together
    count = np.roll(count, 1)
    return count[::2] + count[1::2]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

import matplotlib as mpl

mpl.rcParams.update({'text.color':"white",
                     'axes.labelcolor':"white"})

def polar_plot(ax, bearings, n = 36, title=''):

    bins = np.arange(n + 1) * 360 / n
    count = count_and_merge(n, bearings)
    _, division = np.histogram(bearings, bins=bins)
    frequency = count / count.sum()
    division = division[0:-1]
    width =  2 * np.pi / n

    ax.set_theta_zero_location('N')
    ax.set_theta_direction('clockwise')
    
    norm = colors.Normalize(vmin=min(count)*0.8, vmax=max(count))
    cmap = cm.ScalarMappable(norm=norm, cmap=cm.jet)
    bc = [cmap.to_rgba(cl) for cl in count]

    x = division * np.pi / 180
    bars = ax.bar(x, height=frequency, width=width, align='center', bottom=0, zorder=2, 
                  color=bc, edgecolor='w', linewidth=0.1, alpha=1)
    
    ax.set_ylim(top=frequency.max())
    
    title_font = {'family':'DejaVu Sans', 'size':18, 'weight':'bold'}
    xtick_font = {'family':'DejaVu Sans', 'size':10, 'weight':'bold', 'alpha':1.0, 'zorder':3}
    ytick_font = {'family':'DejaVu Sans', 'size': 9, 'weight':'bold', 'alpha':0.2, 'zorder':3}
    
    ax.set_title(title.upper(), y=1.05, fontdict=title_font)
    
    ax.set_facecolor('k')
    
    ax.set_yticks(np.linspace(0, max(ax.get_ylim()), 5))
    yticklabels = ['{:.2f}'.format(y) for y in ax.get_yticks()]
    yticklabels[0] = ''
    ax.set_yticklabels(labels=yticklabels, fontdict=ytick_font)
    
    xticklabels = ['N', '', 'E', '', 'S', '', 'W', '']
    ax.set_xticklabels(labels=xticklabels, fontdict=xtick_font)
    ax.tick_params(axis='x', which='major', pad=-2)

# %%
filtered = dict((key, value) for key, value in bearings.items() if len(value) > 100)

# %%
print(len(bearings))
print(len(filtered))
# Out:
# 291
# 192

# %%
camps['key'] = pd.Series(np.array(list(bearings.keys())), dtype = 'int')
camps.head()
# Out:
#            X          Y                    name cleaned_name  key
# 0  -6.865540  26.831305     Dakhla Refugee Camp     Dakhla    1.0
# 1  -8.010650  27.513829   Boujdour Refugee Camp   Boujdour    2.0
# 2  -8.023589  27.739910   El Aaiún Refugee Camp   El Aaiún    3.0
# 3  -8.720793   7.025102       Bahn Refugee Camp       Bahn    4.0
# 4  40.286872   0.190007  Dagahaley Refugee Camp  Dagahaley    5.0

# %%
keys = np.array(list(filtered.keys()))

# %%
plots = keys[1:100]

# %%
camps['cleaned_name'] = camps.name.str.replace("camp|refugee|settlement|reffugee|site", "", case = False)

# %%
camps.cleaned_name[72] = "Adi Harush"
camps.cleaned_name[14] = "Gondje"
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
reset = camps.set_index('key')

# %%
keys = np.array(list(filtered.keys()))

trimmed = reset.loc[keys, :]
trimmed.shape
# Out:
# (192, 4)

# %%
len(filtered) == len(trimmed)
# Out:
# True

# %%
n = 100
ncols = int(np.ceil(np.sqrt(n)))
nrows = int(np.ceil(n / ncols))
figsize = (ncols * 5, nrows * 5)
fig, axes = plt.subplots(nrows, ncols, figsize=figsize, subplot_kw={'projection':'polar'})

# plot each city's polar histogram
for ax, camp in zip(axes.flat, plots):
    polar_plot(ax, filtered[camp].dropna(), title=trimmed.cleaned_name[camp])

# add super title and save full image
suptitle_font = {'family':'DejaVu Sans', 'fontsize':60, 'fontweight':'normal', 'y':1.07}
fig.suptitle('Refugee Camp Network Orientation', **suptitle_font)
fig.tight_layout()
fig.subplots_adjust(hspace=0.35)
fig.savefig('street-orientations.png', dpi=120, bbox_inches='tight')
plt.close()

# %%
from scipy import stats

var = []

for key, value in filtered.items():
    var.append(stats.entropy(value))

# %%
trimmed['variance'] = var

# %%
omitna = trimmed.dropna()

# %%
ordered = omitna.sort_values('variance').index.to_numpy()

# %%
plots = ordered[0:100]

# %%
n = 100
ncols = int(np.ceil(np.sqrt(n)))
nrows = int(np.ceil(n / ncols))
figsize = (ncols * 5, nrows * 5)
fig, axes = plt.subplots(nrows, ncols, figsize=figsize, subplot_kw={'projection':'polar'})

# plot each city's polar histogram
for ax, camp in zip(axes.flat, plots):
    polar_plot(ax, filtered[camp].dropna(), title=reset.cleaned_name[camp])

# add super title and save full image
suptitle_font = {'family':'DejaVu Sans', 'fontsize':60, 'fontweight':'normal', 'y':1.07}
fig.suptitle('Refugee Camp Network Orientation', **suptitle_font)
fig.tight_layout()
fig.set_facecolor('k')
fig.subplots_adjust(hspace=0.35)
fig.savefig('street-orientations.png', facecolor=fig.get_facecolor(), dpi=120, bbox_inches='tight')
plt.close()
